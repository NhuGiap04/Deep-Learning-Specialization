# %%
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('Datasets/sp500sub.csv', index_col='Date', parse_dates=True)

# %%
goog = df[df['Name'] == 'GOOG'][['Close']].copy()

# %%
goog.head()
# Out:
#                  Close
# Date
# 2010-01-04  312.204773
# 2010-01-05  310.829926
# 2010-01-06  302.994293
# 2010-01-07  295.940735
# 2010-01-08  299.885956

# %%
goog.columns = ['y']
goog['ds'] = goog.index

# %%
m = Prophet()
m.fit(goog.iloc[-252*2:])
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
fig = m.plot(forecast);
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# 17:48:46 - cmdstanpy - INFO - Chain [1] start processing
# 17:48:46 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
m.plot_components(forecast);
# Out:
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
# BAD!!! From blog articles
m = Prophet(daily_seasonality=True)
m.fit(goog.iloc[-252*3:])
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
fig = m.plot(forecast);
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# 17:48:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:48:55 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
m.plot_components(forecast);
# Out:
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:397: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   artists += ax.plot(df_y['ds'].dt.to_pydatetime(), seas[name], ls='-',
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:401: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
m = Prophet(weekly_seasonality=False)
m.fit(goog.iloc[-252*3:])
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
fig = m.plot(forecast);
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# 17:49:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:49:06 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
m.plot_components(forecast);
# Out:
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %% [markdown]
# ## Cross-Validation

# %%
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric

# %%
m = Prophet(weekly_seasonality=False)

# %%
m.fit(goog[-252*2:])
# Out:
# 17:49:28 - cmdstanpy - INFO - Chain [1] start processing
# 17:49:28 - cmdstanpy - INFO - Chain [1] done processing

# %%
# try period=15, horizon=30
# try period=30, horizon=60
df_cv = cross_validation(
    m,
    initial='365 days',
    period='5 days',
    horizon='5 days')

# %%
df_cv.head(20)
# Out:
#            ds         yhat   yhat_lower   yhat_upper            y     cutoff
# 0  2017-12-29  1066.148781  1052.012233  1079.131193  1046.400024 2017-12-28
# 1  2018-01-02  1070.335229  1056.672762  1083.738517  1065.000000 2017-12-28
# 2  2018-01-03  1065.833887  1051.926286  1078.731815  1082.479980 2018-01-02
# 3  2018-01-04  1066.916090  1052.918288  1081.972386  1086.400024 2018-01-02
# 4  2018-01-05  1068.098758  1053.415524  1081.981735  1102.229980 2018-01-02
# 5  2018-01-08  1086.307170  1071.594050  1099.898309  1106.939941 2018-01-07
# 6  2018-01-09  1088.123416  1074.077635  1101.778268  1106.260010 2018-01-07
# 7  2018-01-10  1089.909693  1075.571510  1102.991154  1102.609985 2018-01-07
# 8  2018-01-11  1091.646471  1077.953815  1105.921058  1105.520020 2018-01-07
# 9  2018-01-12  1093.313666  1078.636886  1106.383490  1122.260010 2018-01-07
# 10 2018-01-16  1110.959604  1096.952938  1125.765481  1121.760010 2018-01-12
# 11 2018-01-17  1111.976247  1096.991064  1126.914561  1131.979980 2018-01-12
# 12 2018-01-18  1116.998113  1102.880642  1129.412894  1129.790039 2018-01-17
# 13 2018-01-19  1117.640295  1104.162758  1130.892166  1137.510010 2018-01-17
# 14 2018-01-22  1118.152944  1104.830083  1131.716105  1155.810059 2018-01-17
# 15 2018-01-23  1133.377069  1119.023883  1147.079280  1169.969971 2018-01-22
# 16 2018-01-24  1133.800118  1119.044377  1148.142065  1164.239990 2018-01-22
# 17 2018-01-25  1134.029783  1119.902105  1148.687939  1170.369995 2018-01-22
# 18 2018-01-26  1134.091593  1119.623678  1147.431402  1175.839966 2018-01-22
# 19 2018-01-29  1163.987316  1150.519654  1179.454403  1175.579956 2018-01-27

# %%
df_cv.shape
# Out:
# (251, 6)

# %%
naive = df_cv[['ds', 'yhat', 'y', 'cutoff']].copy()

# %%
naive_storage = np.zeros(naive.shape[0])
one_day = pd.Timedelta(1, 'day')
for i, row in naive.iterrows():
  cutoff = row['cutoff']
  # print(cutoff)

  # must find last cutoff that actually exists in df
  while cutoff not in goog.index:
    cutoff = cutoff - one_day

  naive_storage[i] = goog.loc[cutoff]['y']

naive['yhat'] = naive_storage

# %%
pm = performance_metrics(df_cv)
pm['smape'].mean()
# Out:
# 0.031235315787641726

# %%
naive_metrics = performance_metrics(naive)
naive_metrics['smape'].mean()
# Out:
# 0.020548255026446992

# %%
plot_cross_validation_metric(df_cv, metric='smape');
# Out:
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %% [markdown]
# ### Cross-Validation with Logged Data

# %%
log_goog = goog.copy()
log_goog['y'] = np.log(goog['y'])

# %%
m = Prophet(weekly_seasonality=False)
m.fit(log_goog[-252*2:])
df_cv = cross_validation(
    m,
    initial='365 days',
    period='30 days',
    horizon='60 days')
pm = performance_metrics(df_cv)
pm['smape'].mean()

# %%
naive = df_cv[['ds', 'yhat', 'y', 'cutoff']].copy()
naive_storage = np.zeros(naive.shape[0])
for i, row in naive.iterrows():
  cutoff = row['cutoff']
  # print(cutoff)

  # must find last cutoff that actually exists in df
  while cutoff not in goog.index:
    cutoff = cutoff - pd.Timedelta(1, 'day')

  naive_storage[i] = log_goog.loc[cutoff]['y']

naive['yhat'] = naive_storage
naive_metrics = performance_metrics(naive)
naive_metrics['smape'].mean()
# Out:
# 0.008361150811971313

# %%
plot_cross_validation_metric(df_cv, metric='smape');
# Out:
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# C:\Users\ADMIN\anaconda3\envs\Tensorflow_GPU\lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
