# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make the original data
series = np.sin(0.1*np.arange(200)) #+ np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (190, 10, 1) Y.shape (190,)

# %%
### try autoregressive RNN model
i = Input(shape=(T, 1))
x = SimpleRNN(15, activation='relu')(i)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(learning_rate=0.001),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]))
# Out:
# Epoch 1/80
# 3/3 [==============================] - 2s 170ms/step - loss: 0.5613 - val_loss: 0.4294
# Epoch 2/80
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5108 - val_loss: 0.3901
# Epoch 3/80
# 3/3 [==============================] - 0s 28ms/step - loss: 0.4683 - val_loss: 0.3561
# Epoch 4/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.4304 - val_loss: 0.3245
# Epoch 5/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.3910 - val_loss: 0.2958
# Epoch 6/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.3565 - val_loss: 0.2688
# Epoch 7/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3213 - val_loss: 0.2439
# Epoch 8/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2864 - val_loss: 0.2205
# Epoch 9/80
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2540 - val_loss: 0.1983
# Epoch 10/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2220 - val_loss: 0.1766
# Epoch 11/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1906 - val_loss: 0.1558
# Epoch 12/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1606 - val_loss: 0.1367
# Epoch 13/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1382 - val_loss: 0.1190
# Epoch 14/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1167 - val_loss: 0.1037
# Epoch 15/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0989 - val_loss: 0.0907
# Epoch 16/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0843 - val_loss: 0.0797
# Epoch 17/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0728 - val_loss: 0.0712
# Epoch 18/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0642 - val_loss: 0.0644
# Epoch 19/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0579 - val_loss: 0.0588
# Epoch 20/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0525 - val_loss: 0.0539
# Epoch 21/80
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0461 - val_loss: 0.0495
# Epoch 22/80
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0405 - val_loss: 0.0455
# Epoch 23/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0356 - val_loss: 0.0421
# Epoch 24/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0318 - val_loss: 0.0389
# Epoch 25/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0293 - val_loss: 0.0357
# Epoch 26/80
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0264 - val_loss: 0.0320
# Epoch 27/80
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0234 - val_loss: 0.0289
# Epoch 28/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0214 - val_loss: 0.0263
# Epoch 29/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0197 - val_loss: 0.0243
# Epoch 30/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0181 - val_loss: 0.0227
# Epoch 31/80
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0168 - val_loss: 0.0214
# Epoch 32/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0156 - val_loss: 0.0201
# Epoch 33/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0147 - val_loss: 0.0187
# Epoch 34/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0137 - val_loss: 0.0173
# Epoch 35/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0128 - val_loss: 0.0162
# Epoch 36/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0120 - val_loss: 0.0152
# Epoch 37/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0114 - val_loss: 0.0142
# Epoch 38/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0106 - val_loss: 0.0133
# Epoch 39/80
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0100 - val_loss: 0.0123
# Epoch 40/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0093 - val_loss: 0.0115
# Epoch 41/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0087 - val_loss: 0.0106
# Epoch 42/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0082 - val_loss: 0.0100
# Epoch 43/80
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0076 - val_loss: 0.0092
# Epoch 44/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0071 - val_loss: 0.0084
# Epoch 45/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0065 - val_loss: 0.0078
# Epoch 46/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0060 - val_loss: 0.0072
# Epoch 47/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0056 - val_loss: 0.0066
# Epoch 48/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0052 - val_loss: 0.0061
# Epoch 49/80
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 50/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0044 - val_loss: 0.0051
# Epoch 51/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 52/80
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 53/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 54/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 55/80
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 56/80
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 57/80
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 58/80
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 59/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 60/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 61/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 62/80
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 63/80
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 64/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 65/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 66/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 67/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 68/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 69/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 70/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 71/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 72/80
# 3/3 [==============================] - 0s 27ms/step - loss: 9.9750e-04 - val_loss: 0.0011
# Epoch 73/80
# 3/3 [==============================] - 0s 30ms/step - loss: 9.3938e-04 - val_loss: 9.9432e-04
# Epoch 74/80
# 3/3 [==============================] - 0s 25ms/step - loss: 8.8719e-04 - val_loss: 9.4217e-04
# Epoch 75/80
# 3/3 [==============================] - 0s 28ms/step - loss: 8.3865e-04 - val_loss: 8.9373e-04
# Epoch 76/80
# 3/3 [==============================] - 0s 29ms/step - loss: 7.9765e-04 - val_loss: 8.5681e-04
# Epoch 77/80
# 3/3 [==============================] - 0s 24ms/step - loss: 7.5776e-04 - val_loss: 8.2533e-04
# Epoch 78/80
# 3/3 [==============================] - 0s 25ms/step - loss: 7.2634e-04 - val_loss: 7.9026e-04
# Epoch 79/80
# 3/3 [==============================] - 0s 24ms/step - loss: 7.0002e-04 - val_loss: 7.4144e-04
# Epoch 80/80
# 3/3 [==============================] - 0s 34ms/step - loss: 6.6961e-04 - val_loss: 7.0955e-04

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  i += 1

  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# first validation input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1, 1))[0,0] # 1x1 array -> scalar

  # update the predictions list
  validation_predictions.append(p)

  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
